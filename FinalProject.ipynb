# %% [markdown]
# # **FINAL PROJECT**

# %% [markdown]
# ## **Code**

# %% [markdown]
# ### **R**

# %% [markdown]
# ![Screenshot 2023-04-30 at 2.14.27 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2023-04-30 at 2.15.47 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2023-04-30 at 2.17.13 PM.png](data:image/png;base64,...)

# %% [markdown]
# ### **Python**

# %%
# Importing packages
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import csv
from scipy import stats
from statsmodels.stats.weightstats import ztest as ztest

# %%
# Reading CSVs 
sen113 = pd.read_csv('senate113.csv')
house113 = pd.read_csv('house113.csv')
sen115 = pd.read_csv('senate115.csv')
house115 = pd.read_csv('house115.csv')
sen117 = pd.read_csv('senate117.csv')
house117 = pd.read_csv('house117.csv')

# %%
print(np.shape(sen113))
print(np.shape(house113))
print(np.shape(sen115))
print(np.shape(house115))
print(np.shape(sen117))
print(np.shape(house117))
# Out:
# (106, 657)
# (445, 1202)
# (106, 599)
# (451, 1207)
# (101, 949)
# (457, 996)

# %%
# Creating a Function that turns dataframe into Adjacency Matrix
def data_to_mat(data):
  data = data.to_numpy()
  data = data[:-1, 2:]

  dims = np.shape(data)

  # Creating Adjacency Matrix
  A = np.zeros((dims[0], dims[0]))

  # Loop through bills
  for i in range(dims[1]):

    # Loop through senators:
    for j in range(dims[0]):

        # Loop through senators in column k
        for k in range(dims[0]):
          # Check for senators in column k that co-sponsored bill i 
          if (data[j, i] == data[k, i]) and (j != k) and (data[j, i] != 9.0):
            A[k, j] += 1
  return A

# %% [markdown]
# **WARNING THE NEXT CODE CHUNK TAKES LONG TIME TO RUN**

# %%
sen113 = data_to_mat(sen113)
house113 = data_to_mat(house113)
sen115 = data_to_mat(sen115)
house115 = data_to_mat(house115)
sen117 = data_to_mat(sen117)
house117 = data_to_mat(house117)

# %% [markdown]
# ### PLOTS

# %%
plt.plot(figsize = (6,6))
plt.title("113th Senate")
plt.imshow(sen113)
plt.colorbar()
plt.show()

plt.plot(figsize = (6,6))
plt.title("115th Senate")
plt.imshow(sen115)
plt.colorbar()
plt.show()

plt.plot(figsize = (6,6))
plt.title("117th Senate")
plt.imshow(sen117)
plt.colorbar()
plt.show()


plt.plot(figsize = (6,6))
plt.title("113th House")
plt.imshow(house113)
plt.colorbar()
plt.show()

plt.plot(figsize = (6,6))
plt.title("115th House")
plt.imshow(house115)
plt.colorbar()
plt.show()


plt.plot(figsize = (6,6))
plt.title("117th House")
plt.imshow(house117)
plt.colorbar()
plt.show()

# %%
# Independents
# 113th Session Senate: Last 2 rows
# 115th Session Senate: Last 2 rows
# 117th Session Senate: Last 2 rows

# %% [markdown]
# ### Significance Testing

# %%
# 113th Session - Senators
sen113 = sen113/655
sen113_dems = sen113[1:60,1:60]
sen113_reps = sen113[60:-2,60:-2]
sen113_demstoreps = sen113[1:60, 60:-2]

# 113th Session - House of Representatives
house113 = house113/1200
house113_dems = house113[1:207,1:207]
house113_reps = house113[207:,207:]
house113_demstoreps = house113[1:207, 207:]

# 115th Session - Senators
sen115 = sen115/597
sen115_dems = sen115[1:50,1:50]
sen115_reps = sen115[50:-2,50:-2]
sen115_demstoreps = sen115[1:50, 50:-2]

# 115th Session - House of Representatives
house115 = house115/1205
house115_dems = house115[1:202,1:202]
house115_reps = house115[202:,202:]
house115_demstoreps = house115[1:202, 202:]

# 117th Session - Senators
sen117 = sen117/947
sen117_dems = sen117[1:51,1:51]
sen117_reps = sen117[51:-2,51:-2]
sen117_demstoreps = sen117[1:51, 51:-2]

# 117th Session - House of Representatives
house117 = house117/994
house117_dems = house117[1:235,1:235]
house117_reps = house117[235:,235:]
house117_demstoreps = house117[1:235, 235:]

# %% [markdown]
# #### Averages

# %%
print("Average for 113th Senate - Democrat")
print(np.mean(sen113_dems))

print("\nAverage for 113th Senate - Republican")
print(np.mean(sen113_reps))

print("\nAverage for 113th Senate - Democrats to Republicans")
print(np.mean(sen113_demstoreps))

print("\nAverage for 113th House of Representatives - Democrat")
print(np.mean(house113_dems))

print("\nAverage for 113th House of Representatives - Republican")
print(np.mean(house113_reps))

print("\nAverage for 113th House of Representatives - Democrats to Republicans")
print(np.mean(house113_demstoreps))

print("Average for 115th Senate - Democrat")
print(np.mean(sen115_dems))

print("\nAverage for 115th Senate - Republican")
print(np.mean(sen115_reps))

print("\nAverage for 115th Senate - Democrats to Republicans")
print(np.mean(sen115_demstoreps))

print("\nAverage for 115th House of Representatives - Democrat")
print(np.mean(house115_dems))

print("\nAverage for 115th House of Representatives - Republican")
print(np.mean(house115_reps))

print("\nAverage for 115th House of Representatives - Democrats to Republicans")
print(np.mean(house115_demstoreps))

print("Average for 117th Senate - Democrat")
print(np.mean(sen117_dems))

print("\nAverage for 117th Senate - Republican")
print(np.mean(sen117_reps))

print("\nAverage for 117th Senate - Democrats to Republicans")
print(np.mean(sen117_demstoreps))

print("\nAverage for 117th House of Representatives - Democrat")
print(np.mean(house117_dems))

print("\nAverage for 117th House of Representatives - Republican")
print(np.mean(house117_reps))

print("\nAverage for 117th House of Representatives - Democrats to Republicans")
print(np.mean(house117_demstoreps))
# Out:
# Average for 113th Senate - Democrat
# 0.7325805737142306
#
# Average for 113th Senate - Republican
# 0.7083952951667706
#
# Average for 113th Senate - Democrats to Republicans
# 0.31891246197498396
#
# Average for 113th House of Representatives - Democrat
# 0.7511246347440853
#
# Average for 113th House of Representatives - Republican
# 0.7909146801023103
#
# Average for 113th House of Representatives - Democrats to Republicans
# 0.2824941283301244
# Average for 115th Senate - Democrat
# 0.7179057860453175
#
# Average for 115th Senate - Republican
# 0.766036185436498
#
# Average for 115th Senate - Democrats to Republicans
# 0.34993991907941707
#
# Average for 115th House of Representatives - Democrat
# 0.777325239782385
#
# Average for 115th House of Representatives - Republican
# 0.7628284204299637
#
# Average for 115th House of Representatives - Democrats to Republicans
# 0.2817974776099425
# Average for 117th Senate - Democrat
# 0.8455248152059134
#
# ...

# %% [markdown]
# #### T - Test

# %%
sen113_demsarray = sen113_dems.flatten()
sen113_repsarray = sen113_reps.flatten()
sen113_demstorepsarray = sen113_demstoreps.flatten()


house113_demsarray = house113_dems.flatten()
house113_repsarray = house113_reps.flatten()
house113_demstorepsarray = house113_demstoreps.flatten()


sen115_demsarray = sen115_dems.flatten()
sen115_repsarray = sen115_reps.flatten()
sen115_demstorepsarray = sen115_demstoreps.flatten()


house115_demsarray = house115_dems.flatten()
house115_repsarray = house115_reps.flatten()
house115_demstorepsarray = house115_demstoreps.flatten()


sen117_demsarray = sen117_dems.flatten()
sen117_repsarray = sen117_reps.flatten()
sen117_demstorepsarray = sen117_demstoreps.flatten()


house117_demsarray = house117_dems.flatten()
house117_repsarray = house117_reps.flatten()
house117_demstorepsarray = house117_demstoreps.flatten()





# Senate t - test
senate_t1, senate_p1 = stats.ttest_ind(sen113_repsarray, sen115_repsarray, equal_var = False)
senate_t2, senate_p2 = stats.ttest_ind(sen113_repsarray, sen117_repsarray, equal_var = False)
senate_t3, senate_p3 = stats.ttest_ind(sen115_repsarray, sen117_repsarray, equal_var = False)

senate_t4, senate_p4 = stats.ttest_ind(sen113_demsarray, sen115_demsarray, equal_var = False)
senate_t5, senate_p5 = stats.ttest_ind(sen113_demsarray, sen117_demsarray, equal_var = False)
senate_t6, senate_p6 = stats.ttest_ind(sen115_demsarray, sen117_demsarray, equal_var = False)

senate_t7, senate_p7 = stats.ttest_ind(sen113_demstorepsarray, sen115_demstorepsarray, equal_var = False)
senate_t8, senate_p8 = stats.ttest_ind(sen113_demstorepsarray, sen117_demstorepsarray, equal_var = False)
senate_t9, senate_p9 = stats.ttest_ind(sen115_demstorepsarray, sen117_demstorepsarray, equal_var = False)

print("Senate")
print("Republicans to Republicans")
print("113 - 115:", senate_p1)
print("113 - 117:", senate_p2)
print("115 - 117:", senate_p3)

print("\nDemocrats to Democrats")
print("113 - 115:", senate_p4)
print("113 - 117:", senate_p5)
print("115 - 117:", senate_p6)

print("\nRepublicans to Democrats")
print("113 - 115:", senate_p7)
print("113 - 117:", senate_p8)
print("115 - 117:", senate_p9)



# House t - test
house_t1, house_p1 = stats.ttest_ind(house113_repsarray, house115_repsarray, equal_var = False)
house_t2, house_p2 = stats.ttest_ind(house113_repsarray, house117_repsarray, equal_var = False)
house_t3, house_p3 = stats.ttest_ind(house115_repsarray, house117_repsarray, equal_var = False)

house_t4, house_p4 = stats.ttest_ind(house113_demsarray, house115_demsarray, equal_var = False)
house_t5, house_p5 = stats.ttest_ind(house113_demsarray, house117_demsarray, equal_var = False)
house_t6, house_p6 = stats.ttest_ind(house115_demsarray, house117_demsarray, equal_var = False)

house_t7, house_p7 = stats.ttest_ind(house113_demstorepsarray, house115_demstorepsarray, equal_var = False)
house_t8, house_p8 = stats.ttest_ind(house113_demstorepsarray, house117_demstorepsarray, equal_var = False)
house_t9, house_p9 = stats.ttest_ind(house115_demstorepsarray, house117_demstorepsarray, equal_var = False)

print("\nHouse")
print("Republicans to Republicans")
print("113 - 115:", house_p1)
print("113 - 117:", house_p2)
print("115 - 117:", house_p3)

print("\nDemocrats to Democrats")
print("113 - 115:", house_p4)
print("113 - 117:", house_p5)
print("115 - 117:", house_p6)

print("\nRepublicans to Democrats")
print("113 - 115:", house_p7)
print("113 - 117:", house_p8)
print("115 - 117:", house_p9)
# Out:
# Senate
# Republicans to Republicans
# 113 - 115: 3.31099947981321e-16
# 113 - 117: 0.49669173376043063
# 115 - 117: 1.1910007669374135e-17
#
# Democrats to Democrats
# 113 - 115: 0.03532588873611652
# 113 - 117: 5.906315277391805e-57
# 115 - 117: 1.544176844917457e-79
#
# Republicans to Democrats
# 113 - 115: 4.9990421736163334e-14
# 113 - 117: 2.5362084537378574e-48
# 115 - 117: 1.3481448258578426e-99
#
# House
# Republicans to Republicans
# 113 - 115: 4.666608602052496e-109
# 113 - 117: 1.618287974286582e-306
# 115 - 117: 5.9042224822046076e-55
#
# Democrats to Democrats
# 113 - 115: 1.0011368765705362e-74
# 113 - 117: 0.0
# 115 - 117: 1.1698366045567734e-286
#
# Republicans to Democrats
# 113 - 115: 0.2697019925898321
# 113 - 117: 0.0
# 115 - 117: 0.0

# %% [markdown]
# #### Cohen's D

# %%
def cohens_d(group1, group2):
    mean1, mean2 = np.mean(group1), np.mean(group2)
    sd1, sd2 = np.std(group1, ddof=1), np.std(group2, ddof=1)
    n1, n2 = len(group1), len(group2)
    
    pooled_sd = np.sqrt(((n1 - 1) * sd1 ** 2 + (n2 - 1) * sd2 ** 2) / (n1 + n2 - 2))
    d = (mean1 - mean2) / pooled_sd
    
    return np.abs(d)

# %%
# Senate Cohens - test
senate_d1 = cohens_d(sen113_repsarray, sen115_repsarray)
senate_d2 = cohens_d(sen113_repsarray, sen117_repsarray)
senate_d3 = cohens_d(sen115_repsarray, sen117_repsarray)

senate_d4 = cohens_d(sen113_demsarray, sen115_demsarray)
senate_d5 = cohens_d(sen113_demsarray, sen117_demsarray)
senate_d6 = cohens_d(sen115_demsarray, sen117_demsarray)

senate_d7 = cohens_d(sen113_demstorepsarray, sen115_demstorepsarray)
senate_d8 = cohens_d(sen113_demstorepsarray, sen117_demstorepsarray)
senate_d9 = cohens_d(sen115_demstorepsarray, sen117_demstorepsarray)

print("Senate")
print("Republicans to Republicans")
print("113 - 115:", senate_d1)
print("113 - 117:", senate_d2)
print("115 - 117:", senate_d3)

print("\nDemocrats to Democrats")
print("113 - 115:", senate_d4)
print("113 - 117:", senate_d5)
print("115 - 117:", senate_d6)

print("\nRepublicans to Democrats")
print("113 - 115:", senate_d7)
print("113 - 117:", senate_d8)
print("115 - 117:", senate_d9)


# House Cohens - test
house_d1 = cohens_d(house113_repsarray, house115_repsarray)
house_d2 = cohens_d(house113_repsarray, house117_repsarray)
house_d3 = cohens_d(house115_repsarray, house117_repsarray)

house_d4 = cohens_d(house113_demsarray, house115_demsarray)
house_d5 = cohens_d(house113_demsarray, house117_demsarray)
house_d6 = cohens_d(house115_demsarray, house117_demsarray)

house_d7 = cohens_d(house113_demstorepsarray, house115_demstorepsarray)
house_d8 = cohens_d(house113_demstorepsarray, house117_demstorepsarray)
house_d9 = cohens_d(house115_demstorepsarray, house117_demstorepsarray)



print("\nHouse")
print("Republicans to Republicans")
print("113 - 115:", house_d1)
print("113 - 117:", house_d2)
print("115 - 117:", house_d3)

print("\nDemocrats to Democrats")
print("113 - 115:", house_d4)
print("113 - 117:", house_d5)
print("115 - 117:", house_d6)

print("\nRepublicans to Democrats")
print("113 - 115:", house_d7)
print("113 - 117:", house_d8)
print("115 - 117:", house_d9)
# Out:
# Senate
# Republicans to Republicans
# 113 - 115: 0.2281249782420201
# 113 - 117: 0.021895000886262006
# 115 - 117: 0.22873402089882003
#
# Democrats to Democrats
# 113 - 115: 0.0529692683099693
# 113 - 117: 0.40430975883278736
# 115 - 117: 0.5491801041204485
#
# Republicans to Democrats
# 113 - 115: 0.2107808318975501
# 113 - 117: 0.4246663016285003
# 115 - 117: 0.6199678360226678
#
# House
# Republicans to Republicans
# 113 - 115: 0.1284632904105085
# 113 - 117: 0.23539670646286978
# 115 - 117: 0.09452586456185062
#
# Democrats to Democrats
# 113 - 115: 0.12749545968301426
# 113 - 117: 0.3377297337392599
# 115 - 117: 0.22800013690576973
#
# Republicans to Democrats
# 113 - 115: 0.00702318278698435
# 113 - 117: 0.5379452008271917
# 115 - 117: 0.5324337265696856
